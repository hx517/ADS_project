# %%
import csv
import pandas as pd
import numpy as np

# %%
aFile = open('green_inbound_2016_4.csv', 'r')
aInfo = csv.reader(aFile)

# %%
a = pd.read_csv(aFile)

# %%
a.head()
# Out:
#   lpep_pickup_datetime  Trip_distance  Pickup_longitude  Pickup_latitude  \
# 0  2016-04-01 00:11:32           1.76        -73.952202        40.790142
# 1  2016-04-01 00:22:16           1.23        -73.953896        40.790695
# 2  2016-04-01 00:11:15           6.86        -73.948196        40.829731
# 3  2016-04-01 00:07:35           6.22        -73.954880        40.722385
# 4  2016-04-01 00:13:32           7.04        -73.986885        40.702423
#
#    Dropoff_longitude  Dropoff_latitude  DOLocationID  PULocationID
# 0         -73.954544         40.773636           263            41
# 1         -73.952744         40.779827           263            41
# 2         -73.955467         40.768848           141            41
# 3         -73.949875         40.780804           263            41
# 4         -73.947281         40.779930           263            48

# %%
treat = a[a['DOLocationID'] != 229]

# %%
treat.to_csv("gc_inbound_treatment2016.csv",index=None)

# %%
control = a[a['DOLocationID'] == 229]

# %%
control.to_csv("gc_inbound_control2016.csv",index=None)

# %%
yctreat = pd.read_csv('yc_inbound_1604_treatment.csv')

# %% [markdown]
# combine treatment

# %%
yctreat=yctreat[['tpep_pickup_datetime','trip_distance','pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude','Loc_ID','LocationID']]

# %%
yctreat.columns=treat.columns

# %%
yctreat.head()
# Out:
#   lpep_pickup_datetime  Trip_distance  Pickup_longitude  Pickup_latitude  \
# 0     2016/4/1 0:00:05           2.12        -73.975677        40.753036
# 1     2016/4/1 0:00:08           1.50        -73.975433        40.755520
# 2     2016/4/1 0:00:16           1.54        -73.959190        40.783016
# 3     2016/4/1 0:00:17           1.47        -73.981857        40.762871
# 4     2016/4/1 0:00:18           3.20        -73.981285        40.744877
#
#    Dropoff_longitude  Dropoff_latitude  DOLocationID  PULocationID
# 0         -73.954971         40.769207           140           162
# 1         -73.958824         40.772175           141           161
# 2         -73.960304         40.767231           141           236
# 3         -73.961731         40.760162           141           230
# 4         -73.952332         40.775719           263           170

# %%
treatment=treat.append(yctreat)

# %%
treatment.head()
# Out:
#   lpep_pickup_datetime  Trip_distance  Pickup_longitude  Pickup_latitude  \
# 0  2016-04-01 00:11:32           1.76        -73.952202        40.790142
# 1  2016-04-01 00:22:16           1.23        -73.953896        40.790695
# 2  2016-04-01 00:11:15           6.86        -73.948196        40.829731
# 3  2016-04-01 00:07:35           6.22        -73.954880        40.722385
# 4  2016-04-01 00:13:32           7.04        -73.986885        40.702423
#
#    Dropoff_longitude  Dropoff_latitude  DOLocationID  PULocationID
# 0         -73.954544         40.773636           263            41
# 1         -73.952744         40.779827           263            41
# 2         -73.955467         40.768848           141            41
# 3         -73.949875         40.780804           263            41
# 4         -73.947281         40.779930           263            48

# %%
treatment.tail()
# Out:
#        lpep_pickup_datetime  Trip_distance  Pickup_longitude  Pickup_latitude  \
# 838301   2016/4/19 19:08:43           2.80        -73.981247        40.741562
# 838302   2016/4/19 19:08:46           0.86        -73.973404        40.758595
# 838303   2016/4/19 19:08:47           1.10        -73.973984        40.764095
# 838304   2016/4/19 19:08:47           1.10        -73.962059        40.770531
# 838305   2016/4/19 19:08:47           0.75        -73.955971        40.779041
#
#         Dropoff_longitude  Dropoff_latitude  DOLocationID  PULocationID
# 838301         -73.951668         40.769688           140           107
# 838302         -73.963249         40.762012           141           161
# 838303         -73.958282         40.764793           141           163
# 838304         -73.947166         40.772587           262           237
# 838305         -73.946823         40.772480           262           236

# %%
treatment.to_csv('2016_inbound_treatment.csv',index = None)

# %%
yccontrol = pd.read_csv('yc_inbound_1604_control.csv')
yccontrol.head()
# Out:
#    OBJECTID  Join_Count  TARGET_FID  Join_Count_1  TARGET_FID_1  Field1  \
# 0         1           1          26             1             1     127
# 1         2           1          85             1             2     286
# 2         3           1         118             1             3     377
# 3         4           1         240             1             4     703
# 4         5           1         312             1             5     897
#
#   tpep_pickup_datetime  trip_distance  pickup_longitude  pickup_latitude  \
# 0     2016/4/1 0:00:24           1.70        -73.953270        40.775822
# 1    2016/4/4 14:36:50           0.97        -73.976852        40.758595
# 2    2016/4/4 14:37:07           9.80        -73.862732        40.768864
# 3    2016/4/4 14:38:02           1.60        -73.955498        40.772793
# 4    2016/4/4 14:38:34           6.70        -74.015755        40.715488
#
#    dropoff_longitude  dropoff_latitude  OBJECTID_1  Shape_Leng  \
# ...

# %%
yccontrol=yccontrol[['tpep_pickup_datetime','trip_distance','pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude','Loc_ID','LocationID']]

# %%
yccontrol.columns=control.columns

# %%
yccontrol.head()
# Out:
#   lpep_pickup_datetime  Trip_distance  Pickup_longitude  Pickup_latitude  \
# 0     2016/4/1 0:00:24           1.70        -73.953270        40.775822
# 1    2016/4/4 14:36:50           0.97        -73.976852        40.758595
# 2    2016/4/4 14:37:07           9.80        -73.862732        40.768864
# 3    2016/4/4 14:38:02           1.60        -73.955498        40.772793
# 4    2016/4/4 14:38:34           6.70        -74.015755        40.715488
#
#    Dropoff_longitude  Dropoff_latitude  DOLocationID  PULocationID
# 0         -73.963928         40.758938           229         263.0
# 1         -73.965286         40.755070           229         161.0
# 2         -73.965958         40.752819           229         138.0
# 3         -73.963730         40.757450           229         141.0
# 4         -73.969589         40.756390           229          13.0

# %%
control=control.append(yccontrol)

# %%
control.to_csv('2016_inbound_control.csv',index = None)

# %%
yc2017 = pd.read_csv('yellow_tripdata_2017-04.csv')

# %%
yc2017.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2017-04-01 00:00:00   2017-04-01 00:15:07                1
# 1         1  2017-04-01 00:00:00   2017-04-01 00:16:23                3
# 2         2  2017-04-01 00:00:00   2017-04-01 10:20:01                1
# 3         1  2017-04-01 00:00:01   2017-04-01 00:37:05                2
# 4         1  2017-04-01 00:00:01   2017-04-01 00:02:56                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.8           1                  N           158           113
# 1            3.7           1                  N            87           158
# 2            0.0           1                  N           264           193
# 3            3.3           1                  N           230             4
# 4            0.7           1                  N           142           143
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %% [markdown]
# inbound

# %%
inbound_treat = yc2017[yc2017.DOLocationID.isin([140,141,262,263])]
inbound_treat.head()
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 5          1  2017-04-01 00:00:01   2017-04-01 00:07:28                1
# 20         1  2017-04-01 00:00:03   2017-04-01 00:18:44                2
# 22         2  2017-04-01 00:00:03   2017-04-01 00:24:37                5
# 24         1  2017-04-01 00:00:04   2017-04-01 00:20:00                1
# 38         2  2017-04-01 00:00:05   2017-04-01 00:02:22                2
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 5            2.20           1                  N           170           263
# 20           3.60           1                  N           164           140
# 22           4.31           1                  N           113           141
# 24           5.00           1                  N           125           263
# 38           0.53           1                  N           141           263
#
# ...

# %%
inbound_treat=inbound_treat[['tpep_pickup_datetime','trip_distance','PULocationID','DOLocationID']]
inbound_treat.head()
# Out:
#    tpep_pickup_datetime  trip_distance  PULocationID  DOLocationID
# 5   2017-04-01 00:00:01           2.20           170           263
# 20  2017-04-01 00:00:03           3.60           164           140
# 22  2017-04-01 00:00:03           4.31           113           141
# 24  2017-04-01 00:00:04           5.00           125           263
# 38  2017-04-01 00:00:05           0.53           141           263

# %%
green = pd.read_csv('green_inbound_2017_4.csv')

# %%
green.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2017-04-01 00:03:54   2017-04-01 00:20:51                  N
# 1         2  2017-04-01 00:00:29   2017-04-01 00:02:44                  N
# 2         2  2017-04-01 00:02:22   2017-04-01 00:02:25                  N
# 3         2  2017-04-01 00:08:15   2017-04-01 00:08:15                  N
# 4         2  2017-04-01 00:00:46   2017-04-01 00:07:40                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1            25            14                1           5.29
# 1           1           263            75                1           0.76
# 2           5           182           182                1           0.00
# 3           1           255           137                1           5.20
# 4           1            89           188                1           1.61
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
green=green[['lpep_pickup_datetime','trip_distance','PULocationID','DOLocationID']]
green.columns = inbound_treat.columns
green = green[green.DOLocationID.isin([140,141,262,263])]
green.head()
inbound_treat = inbound_treat.append(green)

# %%
inbound_treat.head()
# Out:
#    tpep_pickup_datetime  trip_distance  PULocationID  DOLocationID
# 5   2017-04-01 00:00:01           2.20           170           263
# 20  2017-04-01 00:00:03           3.60           164           140
# 22  2017-04-01 00:00:03           4.31           113           141
# 24  2017-04-01 00:00:04           5.00           125           263
# 38  2017-04-01 00:00:05           0.53           141           263

# %%
inbound_treat.to_csv('2017_inbound_treatment.csv',index = None)

# %% [markdown]
# inbound control

# %%
inbound_control = yc2017[yc2017.DOLocationID.isin([229])]
inbound_control.head()
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 90          2  2017-04-01 00:00:18   2017-04-01 00:11:28                1
# 100         2  2017-04-01 00:00:20   2017-04-01 00:06:44                2
# 124         1  2017-04-01 00:00:24   2017-04-01 00:17:15                3
# 132         2  2017-04-01 00:00:25   2017-04-01 00:09:16                4
# 170         2  2017-04-01 00:00:33   2017-04-01 00:16:41                1
#
#      trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 90            2.17           1                  N           186           229
# 100           0.80           1                  N           162           229
# 124           1.70           1                  N           230           229
# 132           1.54           1                  N           236           229
# 170           2.94           1                  N            90           229
#
# ...

# %%
inbound_control=inbound_control[['tpep_pickup_datetime','trip_distance','PULocationID','DOLocationID']]
inbound_control.head()
# Out:
#     tpep_pickup_datetime  trip_distance  PULocationID  DOLocationID
# 90   2017-04-01 00:00:18           2.17           186           229
# 100  2017-04-01 00:00:20           0.80           162           229
# 124  2017-04-01 00:00:24           1.70           230           229
# 132  2017-04-01 00:00:25           1.54           236           229
# 170  2017-04-01 00:00:33           2.94            90           229

# %%
green=green[['tpep_pickup_datetime','trip_distance','PULocationID','DOLocationID']]
green.columns = inbound_control.columns
green = green[green.DOLocationID.isin([229])]
green.head()
inbound_control = inbound_control.append(green)

# %%
inbound_control.to_csv('2017_inbound_control.csv',index = None)

# %% [markdown]
# outbound

# %%
outbound_treat = yc2017[yc2017.PULocationID.isin([140,141,262,263])]
outbound_treat.head()
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 38          2  2017-04-01 00:00:05   2017-04-01 00:02:22                2
# 87          1  2017-04-01 00:00:18   2017-04-01 00:12:46                1
# 91          2  2017-04-01 00:00:18   2017-04-01 00:05:43                2
# 105         1  2017-04-01 00:00:21   2017-04-01 00:13:03                1
# 141         2  2017-04-01 00:00:26   2017-04-01 00:13:27                4
#
#      trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 38            0.53           1                  N           141           263
# 87            2.60           1                  N           263           142
# 91            0.84           1                  N           141           237
# 105           3.00           1                  N           140           186
# 141           2.62           1                  N           263           151
#
# ...

# %%
outbound_treat=outbound_treat[['tpep_pickup_datetime','trip_distance','PULocationID','DOLocationID']]
outbound_treat.head()
# Out:
#     tpep_pickup_datetime  trip_distance  PULocationID  DOLocationID
# 38   2017-04-01 00:00:05           0.53           141           263
# 87   2017-04-01 00:00:18           2.60           263           142
# 91   2017-04-01 00:00:18           0.84           141           237
# 105  2017-04-01 00:00:21           3.00           140           186
# 141  2017-04-01 00:00:26           2.62           263           151

# %%
outbound_treat.to_csv('2017_outbound_treatment.csv',index = None)

# %%
outbound_control = yc2017[yc2017.PULocationID.isin([229])]
outbound_control.head()
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 43          2  2017-04-01 00:00:07   2017-04-01 00:09:50                2
# 65          2  2017-04-01 00:00:12   2017-04-01 00:08:25                1
# 123         1  2017-04-01 00:00:24   2017-04-01 00:25:17                3
# 150         1  2017-04-01 00:00:29   2017-04-01 00:19:02                1
# 240         1  2017-04-30 17:37:23   2017-04-30 17:41:39                4
#
#      trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 43            2.03           1                  N           229           107
# 65            2.52           1                  N           229            75
# 123          10.10           1                  N           229           241
# 150           3.40           1                  N           229            79
# 240           1.00           1                  N           229           162
#
# ...

# %%
outbound_control=outbound_control[['tpep_pickup_datetime','trip_distance','PULocationID','DOLocationID']]
outbound_control.head()
# Out:
#     tpep_pickup_datetime  trip_distance  PULocationID  DOLocationID
# 43   2017-04-01 00:00:07           2.03           229           107
# 65   2017-04-01 00:00:12           2.52           229            75
# 123  2017-04-01 00:00:24          10.10           229           241
# 150  2017-04-01 00:00:29           3.40           229            79
# 240  2017-04-30 17:37:23           1.00           229           162

# %%
outbound_control.to_csv('2017_outbound_control.csv',index = None)
