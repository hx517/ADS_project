# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import geopandas as gpd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
test_area = gpd.read_file("bin/test_area.shp")
control_area = gpd.read_file("bin/control_area.shp")

# %%
test_area.columns
# Out:
# Index([u'Id', u'geometry'], dtype='object')

# %%
control_area.head()
# Out:
#    Id                                           geometry
# 0   0  POLYGON ((994745.1616210938 216206.1110839844,...

# %%
fig = plt.figure(figsize=[8,10])
ax = fig.add_subplot(111)
ax.set_aspect('equal')
test_area.plot(column='Id',ax=ax,alpha=0.6)

# %%
fig = plt.figure(figsize=[6,5])
ax = fig.add_subplot(111)
ax.set_aspect('equal')
control_area.plot(column='Id',ax=ax,alpha=1)
