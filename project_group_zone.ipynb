# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import geopandas as gpd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
testgroup = gpd.read_file("bin/test_group.shp")
controlgroup = gpd.read_file("bin/control_group.shp")

# %%
testgroup.columns
# Out:
# Index([   u'ZIPCODE',    u'BLDGZIP',    u'PO_NAME', u'POPULATION',
#              u'AREA',      u'STATE',     u'COUNTY',    u'ST_FIPS',
#          u'CTY_FIPS',        u'URL', u'SHAPE_AREA',  u'SHAPE_LEN',
#          u'geometry'],
#       dtype='object')

# %%
controlgroup.head()
# Out:
#    Id                                           geometry
# 0   0  POLYGON ((982629.6689112335 214640.2400606275,...

# %%
fig = plt.figure(figsize=[10,13])
ax = fig.add_subplot(111)
ax.set_aspect('equal')
testgroup.plot(column='BLDGZIP',ax=ax,alpha=1)

# %%
fig = plt.figure(figsize=[10,13])
ax = fig.add_subplot(111)
ax.set_aspect('equal')
controlgroup.plot(column='Id',ax=ax,alpha=1)
